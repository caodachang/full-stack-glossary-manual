# %% [markdown]
# # WebSocket

# %% [markdown]
# ## WebSocket 是什么？
#
# **WebSocket** 是跑在 TCP 上的全双工协议。和 HTTP 的关键区别：

# %% [markdown]
# ---
#
# ## 本篇出现的新名词速查
#
# | 名词 | 一句话解释 |
# |------|-----------|
# | WebSocket | 全双工长连接协议，浏览器和服务器随时互相发消息 |
# | 全双工 | 双方可以同时收发数据，不像 HTTP 的回合制 |
